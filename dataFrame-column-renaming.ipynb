# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'key1' : ['a','a','b','b','a'],
                   'key2' : ['one', 'two', 'one', 'two', 'one'],
                   'data' : np.random.rand(5)})

# %%
df
# Out:
#        data key1 key2
# 0  0.957046    a  one
# 1  0.749348    a  two
# 2  0.904373    b  one
# 3  0.199799    b  two
# 4  0.525696    a  one

# %%
cols = df.columns.values
cols[cols == 'data'] = 'something'
df.columns = cols

# %%
df
# Out:
#    something key1 key2
# 0   0.957046    a  one
# 1   0.749348    a  two
# 2   0.904373    b  one
# 3   0.199799    b  two
# 4   0.525696    a  one

# %%
dg = pd.DataFrame({'key1' : ['a','a','b','b','a'],
                   'key3' : ['three', 'two', 'zero', 'two', 'one'],
                   'data' : np.random.rand(5)})

# %%
dg
# Out:
#        data key1   key3
# 0  0.056539    a  three
# 1  0.360325    a    two
# 2  0.767408    b   zero
# 3  0.810197    b    two
# 4  0.652636    a    one

# %%
df.merge(dg, how='inner'){{}}{}
# Out:
#     something key1 key2      data   key3
# 0    0.957046    a  one  0.056539  three
# 1    0.957046    a  one  0.360325    two
# 2    0.957046    a  one  0.652636    one
# 3    0.749348    a  two  0.056539  three
# 4    0.749348    a  two  0.360325    two
# 5    0.749348    a  two  0.652636    one
# 6    0.525696    a  one  0.056539  three
# 7    0.525696    a  one  0.360325    two
# 8    0.525696    a  one  0.652636    one
# 9    0.904373    b  one  0.767408   zero
# 10   0.904373    b  one  0.810197    two
# 11   0.199799    b  two  0.767408   zero
# 12   0.199799    b  two  0.810197    two

# %%
df.merge(dg)
# Out:
#     something key1 key2      data   key3
# 0    0.957046    a  one  0.056539  three
# 1    0.957046    a  one  0.360325    two
# 2    0.957046    a  one  0.652636    one
# 3    0.749348    a  two  0.056539  three
# 4    0.749348    a  two  0.360325    two
# 5    0.749348    a  two  0.652636    one
# 6    0.525696    a  one  0.056539  three
# 7    0.525696    a  one  0.360325    two
# 8    0.525696    a  one  0.652636    one
# 9    0.904373    b  one  0.767408   zero
# 10   0.904373    b  one  0.810197    two
# 11   0.199799    b  two  0.767408   zero
# 12   0.199799    b  two  0.810197    two

# %%
{}
